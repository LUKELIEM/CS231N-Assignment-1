# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 100 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength
import time
from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [5e-9, 8e-9, 9e-9, 1e-8, 2e-8, 3e-8, 5e-8, 1e-7]
regularization_strengths = [5e5, 8e5, 1e6, 2e6, 5e6, 1e7, 5e7, 1e8]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for learning_rate in learning_rates:
    for reg in regularization_strengths:
    
        # Train the SVM model using training data
        svm = LinearSVM()
        tic = time.time()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate, reg,
                      num_iters=500, verbose=False)

        # Evaluate performance on training and validation data  
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        
        results[(learning_rate, reg)]=(train_accuracy,val_accuracy)
        
        if (val_accuracy > best_val):
            best_val = val_accuracy
            best_svm = svm
            best_hparam = (learning_rate, reg)
            
        # Output results
        print 'Learning rate is %e' % learning_rate
        print 'Regularization Strength is %e' % reg
        print 'training accuracy: %f' % train_accuracy
        print 'validation accuracy: %f' % val_accuracy  
        toc = time.time()
        print 'That took %fs' % (toc - tic)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# Learning rate is 5.000000e-09
# Regularization Strength is 5.000000e+05
# training accuracy: 0.090939
# validation accuracy: 0.082000
# That took 0.998000s
# Learning rate is 5.000000e-09
# Regularization Strength is 8.000000e+05
# training accuracy: 0.103367
# validation accuracy: 0.096000
# That took 0.977000s
# Learning rate is 5.000000e-09
# Regularization Strength is 1.000000e+06
# training accuracy: 0.109265
# validation accuracy: 0.131000
# That took 0.970000s
# Learning rate is 5.000000e-09
# Regularization Strength is 2.000000e+06
# training accuracy: 0.113918
# validation accuracy: 0.099000
# That took 1.031000s
# Learning rate is 5.000000e-09
# Regularization Strength is 5.000000e+06
# training accuracy: 0.409469
# validation accuracy: 0.424000
# That took 1.030000s
# Learning rate is 5.000000e-09
# Regularization Strength is 1.000000e+07
# training accuracy: 0.415816
# validation accuracy: 0.435000
# That took 0.974000s
# Learning rate is 5.000000e-09
# Regularization Strength is 5.000000e+07
# training accuracy: 0.368367
# validation accuracy: 0.383000
# That took 0.981000s
# Learning rate is 5.000000e-09
# Regularization Strength is 1.000000e+08
# training accuracy: 0.358449
# validation accuracy: 0.388000
# That took 1.093000s
# Learning rate is 8.000000e-09
# Regularization Strength is 5.000000e+05
# training accuracy: 0.090959
# validation accuracy: 0.117000
# That took 0.985000s
# Learning rate is 8.000000e-09
# Regularization Strength is 8.000000e+05
# training accuracy: 0.098020
# validation accuracy: 0.100000
# That took 1.067000s
# Learning rate is 8.000000e-09
# Regularization Strength is 1.000000e+06
# training accuracy: 0.129551
# validation accuracy: 0.114000
# That took 1.101000s
# Learning rate is 8.000000e-09
# Regularization Strength is 2.000000e+06
# training accuracy: 0.276714
# validation accuracy: 0.299000
# That took 0.985000s
# Learning rate is 8.000000e-09
# Regularization Strength is 5.000000e+06
# training accuracy: 0.406245
# validation accuracy: 0.428000
# That took 0.991000s
# Learning rate is 8.000000e-09
# Regularization Strength is 1.000000e+07
# training accuracy: 0.408714
# validation accuracy: 0.418000
# That took 1.034000s
# Learning rate is 8.000000e-09
# Regularization Strength is 5.000000e+07
# training accuracy: 0.361796
# validation accuracy: 0.360000
# That took 1.002000s
# Learning rate is 8.000000e-09
# Regularization Strength is 1.000000e+08
# training accuracy: 0.358122
# validation accuracy: 0.360000
# That took 1.039000s
# Learning rate is 9.000000e-09
# Regularization Strength is 5.000000e+05
# training accuracy: 0.108633
# validation accuracy: 0.102000
# That took 1.002000s
# Learning rate is 9.000000e-09
# Regularization Strength is 8.000000e+05
# training accuracy: 0.092265
# validation accuracy: 0.086000
# That took 0.993000s
# Learning rate is 9.000000e-09
# Regularization Strength is 1.000000e+06
# training accuracy: 0.113347
# validation accuracy: 0.112000
# That took 1.069000s
# Learning rate is 9.000000e-09
# Regularization Strength is 2.000000e+06
# training accuracy: 0.377531
# validation accuracy: 0.382000
# That took 1.054000s
# Learning rate is 9.000000e-09
# Regularization Strength is 5.000000e+06
# training accuracy: 0.413102
# validation accuracy: 0.434000
# That took 1.004000s
# Learning rate is 9.000000e-09
# Regularization Strength is 1.000000e+07
# training accuracy: 0.406347
# validation accuracy: 0.420000
# That took 0.979000s
# Learning rate is 9.000000e-09
# Regularization Strength is 5.000000e+07
# training accuracy: 0.372714
# validation accuracy: 0.383000
# That took 1.041000s
# Learning rate is 9.000000e-09
# Regularization Strength is 1.000000e+08
# training accuracy: 0.318714
# validation accuracy: 0.340000
# That took 0.985000s
# Learning rate is 1.000000e-08
# Regularization Strength is 5.000000e+05
# training accuracy: 0.126633
# validation accuracy: 0.123000
# That took 1.055000s
# Learning rate is 1.000000e-08
# Regularization Strength is 8.000000e+05
# training accuracy: 0.109102
# validation accuracy: 0.134000
# That took 0.964000s
# Learning rate is 1.000000e-08
# Regularization Strength is 1.000000e+06
# training accuracy: 0.096673
# validation accuracy: 0.089000
# That took 1.126000s
# Learning rate is 1.000000e-08
# Regularization Strength is 2.000000e+06
# training accuracy: 0.411347
# validation accuracy: 0.430000
# That took 1.063000s
# Learning rate is 1.000000e-08
# Regularization Strength is 5.000000e+06
# training accuracy: 0.414612
# validation accuracy: 0.413000
# That took 0.965000s
# Learning rate is 1.000000e-08
# Regularization Strength is 1.000000e+07
# training accuracy: 0.405714
# validation accuracy: 0.417000
# That took 1.019000s
# Learning rate is 1.000000e-08
# Regularization Strength is 5.000000e+07
# training accuracy: 0.357388
# validation accuracy: 0.364000
# That took 1.019000s
# Learning rate is 1.000000e-08
# Regularization Strength is 1.000000e+08
# training accuracy: 0.333714
# validation accuracy: 0.359000
# That took 1.116000s
# Learning rate is 2.000000e-08
# Regularization Strength is 5.000000e+05
# training accuracy: 0.137061
# validation accuracy: 0.132000
# That took 1.172000s
# Learning rate is 2.000000e-08
# Regularization Strength is 8.000000e+05
# training accuracy: 0.358429
# validation accuracy: 0.360000
# That took 1.057000s
# Learning rate is 2.000000e-08
# Regularization Strength is 1.000000e+06
# training accuracy: 0.411408
# validation accuracy: 0.427000
# That took 1.145000s
# Learning rate is 2.000000e-08
# Regularization Strength is 2.000000e+06
# training accuracy: 0.413531
# validation accuracy: 0.436000
# That took 1.001000s
# Learning rate is 2.000000e-08
# Regularization Strength is 5.000000e+06
# training accuracy: 0.409755
# validation accuracy: 0.423000
# That took 1.101000s
# Learning rate is 2.000000e-08
# Regularization Strength is 1.000000e+07
# training accuracy: 0.377531
# validation accuracy: 0.386000
# That took 1.013000s
# Learning rate is 2.000000e-08
# Regularization Strength is 5.000000e+07
# training accuracy: 0.312755
# validation accuracy: 0.278000
# That took 1.133000s
# Learning rate is 2.000000e-08
# Regularization Strength is 1.000000e+08
# training accuracy: 0.109959
# validation accuracy: 0.106000
# That took 0.984000s
# Learning rate is 3.000000e-08
# Regularization Strength is 5.000000e+05
# training accuracy: 0.346531
# validation accuracy: 0.380000
# That took 1.094000s
# Learning rate is 3.000000e-08
# Regularization Strength is 8.000000e+05
# training accuracy: 0.411898
# validation accuracy: 0.426000
# That took 0.955000s
# Learning rate is 3.000000e-08
# Regularization Strength is 1.000000e+06
# training accuracy: 0.409041
# validation accuracy: 0.428000
# That took 1.127000s
# Learning rate is 3.000000e-08
# Regularization Strength is 2.000000e+06
# training accuracy: 0.408837
# validation accuracy: 0.429000
# That took 1.108000s
# Learning rate is 3.000000e-08
# Regularization Strength is 5.000000e+06
# training accuracy: 0.397367
# validation accuracy: 0.396000
# That took 1.121000s
# Learning rate is 3.000000e-08
# Regularization Strength is 1.000000e+07
# training accuracy: 0.383653
# validation accuracy: 0.394000
# That took 1.003000s
# Learning rate is 3.000000e-08
# Regularization Strength is 5.000000e+07
# training accuracy: 0.252980
# validation accuracy: 0.278000
# That took 1.031000s
# Learning rate is 3.000000e-08
# Regularization Strength is 1.000000e+08
# training accuracy: 0.095163
# validation accuracy: 0.079000
# That took 1.053000s
# Learning rate is 5.000000e-08
# Regularization Strength is 5.000000e+05
# training accuracy: 0.414408
# validation accuracy: 0.423000
# That took 1.066000s
# Learning rate is 5.000000e-08
# Regularization Strength is 8.000000e+05
# training accuracy: 0.404653
# validation accuracy: 0.421000
# That took 1.066000s
# Learning rate is 5.000000e-08
# Regularization Strength is 1.000000e+06
# training accuracy: 0.408939
# validation accuracy: 0.425000
# That took 1.113000s
# Learning rate is 5.000000e-08
# Regularization Strength is 2.000000e+06
# training accuracy: 0.392306
# validation accuracy: 0.417000
# That took 1.005000s
# Learning rate is 5.000000e-08
# Regularization Strength is 5.000000e+06
# training accuracy: 0.382694
# validation accuracy: 0.388000
# That took 1.117000s
# Learning rate is 5.000000e-08
# Regularization Strength is 1.000000e+07
# training accuracy: 0.372918
# validation accuracy: 0.388000
# That took 1.053000s
# Learning rate is 5.000000e-08
# Regularization Strength is 5.000000e+07
# training accuracy: 0.114163
# validation accuracy: 0.135000
# That took 1.178000s
# Learning rate is 5.000000e-08
# Regularization Strength is 1.000000e+08
# training accuracy: 0.107163
# validation accuracy: 0.125000
# That took 1.170000s
# Learning rate is 1.000000e-07
# Regularization Strength is 5.000000e+05
# training accuracy: 0.402082
# validation accuracy: 0.428000
# That took 1.001000s
# Learning rate is 1.000000e-07
# Regularization Strength is 8.000000e+05
# training accuracy: 0.414388
# validation accuracy: 0.425000
# That took 1.054000s
# Learning rate is 1.000000e-07
# Regularization Strength is 1.000000e+06
# training accuracy: 0.402224
# validation accuracy: 0.402000
# That took 1.010000s
# Learning rate is 1.000000e-07
# Regularization Strength is 2.000000e+06
# training accuracy: 0.386898
# validation accuracy: 0.387000
# That took 1.048000s
# Learning rate is 1.000000e-07
# Regularization Strength is 5.000000e+06
# training accuracy: 0.358388
# validation accuracy: 0.387000
# That took 1.031000s
# Learning rate is 1.000000e-07
# Regularization Strength is 1.000000e+07
# training accuracy: 0.339776
# validation accuracy: 0.357000
# That took 1.106000s
# Learning rate is 1.000000e-07
# Regularization Strength is 5.000000e+07
# training accuracy: 0.093816
# validation accuracy: 0.096000
# That took 1.064000s
# Learning rate is 1.000000e-07
# Regularization Strength is 1.000000e+08
# training accuracy: 0.100265
# validation accuracy: 0.087000
# That took 1.011000s
# lr 5.000000e-09 reg 5.000000e+05 train accuracy: 0.090939 val accuracy: 0.082000
# lr 5.000000e-09 reg 8.000000e+05 train accuracy: 0.103367 val accuracy: 0.096000
# lr 5.000000e-09 reg 1.000000e+06 train accuracy: 0.109265 val accuracy: 0.131000
# lr 5.000000e-09 reg 2.000000e+06 train accuracy: 0.113918 val accuracy: 0.099000
# lr 5.000000e-09 reg 5.000000e+06 train accuracy: 0.409469 val accuracy: 0.424000
# lr 5.000000e-09 reg 1.000000e+07 train accuracy: 0.415816 val accuracy: 0.435000
# lr 5.000000e-09 reg 5.000000e+07 train accuracy: 0.368367 val accuracy: 0.383000
# lr 5.000000e-09 reg 1.000000e+08 train accuracy: 0.358449 val accuracy: 0.388000
# lr 8.000000e-09 reg 5.000000e+05 train accuracy: 0.090959 val accuracy: 0.117000
# lr 8.000000e-09 reg 8.000000e+05 train accuracy: 0.098020 val accuracy: 0.100000
# lr 8.000000e-09 reg 1.000000e+06 train accuracy: 0.129551 val accuracy: 0.114000
# lr 8.000000e-09 reg 2.000000e+06 train accuracy: 0.276714 val accuracy: 0.299000
# lr 8.000000e-09 reg 5.000000e+06 train accuracy: 0.406245 val accuracy: 0.428000
# lr 8.000000e-09 reg 1.000000e+07 train accuracy: 0.408714 val accuracy: 0.418000
# lr 8.000000e-09 reg 5.000000e+07 train accuracy: 0.361796 val accuracy: 0.360000
# lr 8.000000e-09 reg 1.000000e+08 train accuracy: 0.358122 val accuracy: 0.360000
# lr 9.000000e-09 reg 5.000000e+05 train accuracy: 0.108633 val accuracy: 0.102000
# lr 9.000000e-09 reg 8.000000e+05 train accuracy: 0.092265 val accuracy: 0.086000
# lr 9.000000e-09 reg 1.000000e+06 train accuracy: 0.113347 val accuracy: 0.112000
# lr 9.000000e-09 reg 2.000000e+06 train accuracy: 0.377531 val accuracy: 0.382000
# lr 9.000000e-09 reg 5.000000e+06 train accuracy: 0.413102 val accuracy: 0.434000
# lr 9.000000e-09 reg 1.000000e+07 train accuracy: 0.406347 val accuracy: 0.420000
# lr 9.000000e-09 reg 5.000000e+07 train accuracy: 0.372714 val accuracy: 0.383000
# lr 9.000000e-09 reg 1.000000e+08 train accuracy: 0.318714 val accuracy: 0.340000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.126633 val accuracy: 0.123000
# lr 1.000000e-08 reg 8.000000e+05 train accuracy: 0.109102 val accuracy: 0.134000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.096673 val accuracy: 0.089000
# lr 1.000000e-08 reg 2.000000e+06 train accuracy: 0.411347 val accuracy: 0.430000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.414612 val accuracy: 0.413000
# lr 1.000000e-08 reg 1.000000e+07 train accuracy: 0.405714 val accuracy: 0.417000
# lr 1.000000e-08 reg 5.000000e+07 train accuracy: 0.357388 val accuracy: 0.364000
# lr 1.000000e-08 reg 1.000000e+08 train accuracy: 0.333714 val accuracy: 0.359000
# lr 2.000000e-08 reg 5.000000e+05 train accuracy: 0.137061 val accuracy: 0.132000
# lr 2.000000e-08 reg 8.000000e+05 train accuracy: 0.358429 val accuracy: 0.360000
# lr 2.000000e-08 reg 1.000000e+06 train accuracy: 0.411408 val accuracy: 0.427000
# lr 2.000000e-08 reg 2.000000e+06 train accuracy: 0.413531 val accuracy: 0.436000
# lr 2.000000e-08 reg 5.000000e+06 train accuracy: 0.409755 val accuracy: 0.423000
# lr 2.000000e-08 reg 1.000000e+07 train accuracy: 0.377531 val accuracy: 0.386000
# lr 2.000000e-08 reg 5.000000e+07 train accuracy: 0.312755 val accuracy: 0.278000
# lr 2.000000e-08 reg 1.000000e+08 train accuracy: 0.109959 val accuracy: 0.106000
# lr 3.000000e-08 reg 5.000000e+05 train accuracy: 0.346531 val accuracy: 0.380000
# lr 3.000000e-08 reg 8.000000e+05 train accuracy: 0.411898 val accuracy: 0.426000
# lr 3.000000e-08 reg 1.000000e+06 train accuracy: 0.409041 val accuracy: 0.428000
# lr 3.000000e-08 reg 2.000000e+06 train accuracy: 0.408837 val accuracy: 0.429000
# lr 3.000000e-08 reg 5.000000e+06 train accuracy: 0.397367 val accuracy: 0.396000
# lr 3.000000e-08 reg 1.000000e+07 train accuracy: 0.383653 val accuracy: 0.394000
# lr 3.000000e-08 reg 5.000000e+07 train accuracy: 0.252980 val accuracy: 0.278000
# lr 3.000000e-08 reg 1.000000e+08 train accuracy: 0.095163 val accuracy: 0.079000
# lr 5.000000e-08 reg 5.000000e+05 train accuracy: 0.414408 val accuracy: 0.423000
# lr 5.000000e-08 reg 8.000000e+05 train accuracy: 0.404653 val accuracy: 0.421000
# lr 5.000000e-08 reg 1.000000e+06 train accuracy: 0.408939 val accuracy: 0.425000
# lr 5.000000e-08 reg 2.000000e+06 train accuracy: 0.392306 val accuracy: 0.417000
# lr 5.000000e-08 reg 5.000000e+06 train accuracy: 0.382694 val accuracy: 0.388000
# lr 5.000000e-08 reg 1.000000e+07 train accuracy: 0.372918 val accuracy: 0.388000
# lr 5.000000e-08 reg 5.000000e+07 train accuracy: 0.114163 val accuracy: 0.135000
# lr 5.000000e-08 reg 1.000000e+08 train accuracy: 0.107163 val accuracy: 0.125000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.402082 val accuracy: 0.428000
# lr 1.000000e-07 reg 8.000000e+05 train accuracy: 0.414388 val accuracy: 0.425000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.402224 val accuracy: 0.402000
# lr 1.000000e-07 reg 2.000000e+06 train accuracy: 0.386898 val accuracy: 0.387000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.358388 val accuracy: 0.387000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.339776 val accuracy: 0.357000
# lr 1.000000e-07 reg 5.000000e+07 train accuracy: 0.093816 val accuracy: 0.096000
# lr 1.000000e-07 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.436000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.418

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8

# First provide images that our system gets RIGHT
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test == cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# Then provide images that our system gets WRONG
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
print X_val_feats.shape
# Out:
# (49000L, 245L)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
num_classes = 10
learning_rates = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
regularization_strengths = [2e-4, 5e-4, 1e-3, 3e-3]
hidden_sizes = [500,800]
results={}

best_val = -1
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
for hidden_size in hidden_sizes:
    print "********* Num hidden units: %d *************" % hidden_size 
    for learning_rate in learning_rates:
        for reg in regularization_strengths:
            
            tic = time.time()
            
            # Set up neural net
            net = TwoLayerNet(input_dim, hidden_size, num_classes)

            # Train the network
            stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                    num_iters=600, batch_size=200,
                    learning_rate=learning_rate, learning_rate_decay=0.95,
                    reg=reg, verbose=False)

            # Predict on the validation set
            val_acc = (net.predict(X_val_feats) == y_val).mean()
            results[(hidden_size, learning_rate, reg)]=(val_acc)
            
            if (val_acc > best_val):
                best_val = val_acc
                best_net = net
                best_hparam = (hidden_size, learning_rate, reg)
                
            print "Learning rate: %e" % learning_rate
            print "Regularization: %f" % reg
            print 'Validation accuracy: ', val_acc
            toc = time.time()
            print 'That took %fs' % (toc - tic)
            
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Print out results.
for nh, lr, reg in sorted(results):
    val_accuracy = results[(nh, lr, reg)]
    print 'nh %d lr %e reg %e val accuracy: %f' % (
                nh, lr, reg, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
print 'hyperparameters (hidden_size, learning_rate, reg) are %s' % (best_hparam,)
# Out:
# ********* Num hidden units: 500 *************
# Learning rate: 5.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.546
# That took 6.245000s
# Learning rate: 5.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.528
# That took 6.444000s
# Learning rate: 5.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.542
# That took 6.290000s
# Learning rate: 5.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.548
# That took 6.745000s
# Learning rate: 6.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.569
# That took 6.437000s
# Learning rate: 6.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.571
# That took 6.334000s
# Learning rate: 6.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.545
# That took 6.422000s
# Learning rate: 6.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.532
# That took 6.304000s
# Learning rate: 7.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.564
# That took 7.118000s
# Learning rate: 7.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.559
# That took 6.326000s
# Learning rate: 7.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.558
# That took 6.480000s
# Learning rate: 7.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.537
# That took 6.244000s
# Learning rate: 8.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.539
# That took 6.317000s
# Learning rate: 8.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.56
# That took 6.360000s
# Learning rate: 8.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.555
# That took 6.446000s
# Learning rate: 8.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.528
# That took 6.341000s
# Learning rate: 9.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.521
# That took 6.381000s
# Learning rate: 9.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.554
# That took 6.150000s
# Learning rate: 9.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.546
# That took 6.271000s
# Learning rate: 9.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.52
# That took 6.281000s
# Learning rate: 1.000000e+00
# Regularization: 0.000200
# Validation accuracy:  0.524
# That took 6.017000s
# Learning rate: 1.000000e+00
# Regularization: 0.000500
# Validation accuracy:  0.565
# That took 6.231000s
# Learning rate: 1.000000e+00
# Regularization: 0.001000
# Validation accuracy:  0.531
# That took 6.316000s
# Learning rate: 1.000000e+00
# Regularization: 0.003000
# Validation accuracy:  0.555
# That took 6.163000s
# ********* Num hidden units: 800 *************
# Learning rate: 5.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.575
# That took 12.340000s
# Learning rate: 5.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.542
# That took 12.651000s
# Learning rate: 5.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.55
# That took 12.767000s
# Learning rate: 5.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.552
# That took 13.054000s
# Learning rate: 6.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.551
# That took 12.695000s
# Learning rate: 6.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.552
# That took 12.659000s
# Learning rate: 6.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.571
# That took 12.579000s
# Learning rate: 6.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.546
# That took 12.661000s
# Learning rate: 7.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.543
# That took 14.294000s
# Learning rate: 7.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.541
# That took 13.425000s
# Learning rate: 7.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.523
# That took 13.114000s
# Learning rate: 7.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.563
# That took 13.382000s
# Learning rate: 8.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.527
# That took 13.120000s
# Learning rate: 8.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.55
# That took 13.276000s
# Learning rate: 8.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.526
# That took 13.200000s
# Learning rate: 8.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.544
# That took 13.180000s
# Learning rate: 9.000000e-01
# Regularization: 0.000200
# Validation accuracy:  0.54
# That took 12.914000s
# Learning rate: 9.000000e-01
# Regularization: 0.000500
# Validation accuracy:  0.515
# That took 13.158000s
# Learning rate: 9.000000e-01
# Regularization: 0.001000
# Validation accuracy:  0.528
# That took 12.840000s
# Learning rate: 9.000000e-01
# Regularization: 0.003000
# Validation accuracy:  0.507
# That took 12.767000s
# Learning rate: 1.000000e+00
# Regularization: 0.000200
# Validation accuracy:  0.55
# That took 12.570000s
# Learning rate: 1.000000e+00
# Regularization: 0.000500
# Validation accuracy:  0.551
# That took 12.646000s
# Learning rate: 1.000000e+00
# Regularization: 0.001000
# Validation accuracy:  0.541
# That took 12.659000s
# Learning rate: 1.000000e+00
# Regularization: 0.003000
# Validation accuracy:  0.54
# That took 12.663000s
# nh 500 lr 5.000000e-01 reg 2.000000e-04 val accuracy: 0.546000
# nh 500 lr 5.000000e-01 reg 5.000000e-04 val accuracy: 0.528000
# nh 500 lr 5.000000e-01 reg 1.000000e-03 val accuracy: 0.542000
# nh 500 lr 5.000000e-01 reg 3.000000e-03 val accuracy: 0.548000
# nh 500 lr 6.000000e-01 reg 2.000000e-04 val accuracy: 0.569000
# nh 500 lr 6.000000e-01 reg 5.000000e-04 val accuracy: 0.571000
# nh 500 lr 6.000000e-01 reg 1.000000e-03 val accuracy: 0.545000
# nh 500 lr 6.000000e-01 reg 3.000000e-03 val accuracy: 0.532000
# nh 500 lr 7.000000e-01 reg 2.000000e-04 val accuracy: 0.564000
# nh 500 lr 7.000000e-01 reg 5.000000e-04 val accuracy: 0.559000
# nh 500 lr 7.000000e-01 reg 1.000000e-03 val accuracy: 0.558000
# nh 500 lr 7.000000e-01 reg 3.000000e-03 val accuracy: 0.537000
# nh 500 lr 8.000000e-01 reg 2.000000e-04 val accuracy: 0.539000
# nh 500 lr 8.000000e-01 reg 5.000000e-04 val accuracy: 0.560000
# nh 500 lr 8.000000e-01 reg 1.000000e-03 val accuracy: 0.555000
# nh 500 lr 8.000000e-01 reg 3.000000e-03 val accuracy: 0.528000
# nh 500 lr 9.000000e-01 reg 2.000000e-04 val accuracy: 0.521000
# nh 500 lr 9.000000e-01 reg 5.000000e-04 val accuracy: 0.554000
# nh 500 lr 9.000000e-01 reg 1.000000e-03 val accuracy: 0.546000
# nh 500 lr 9.000000e-01 reg 3.000000e-03 val accuracy: 0.520000
# nh 500 lr 1.000000e+00 reg 2.000000e-04 val accuracy: 0.524000
# nh 500 lr 1.000000e+00 reg 5.000000e-04 val accuracy: 0.565000
# nh 500 lr 1.000000e+00 reg 1.000000e-03 val accuracy: 0.531000
# nh 500 lr 1.000000e+00 reg 3.000000e-03 val accuracy: 0.555000
# nh 800 lr 5.000000e-01 reg 2.000000e-04 val accuracy: 0.575000
# nh 800 lr 5.000000e-01 reg 5.000000e-04 val accuracy: 0.542000
# nh 800 lr 5.000000e-01 reg 1.000000e-03 val accuracy: 0.550000
# nh 800 lr 5.000000e-01 reg 3.000000e-03 val accuracy: 0.552000
# nh 800 lr 6.000000e-01 reg 2.000000e-04 val accuracy: 0.551000
# nh 800 lr 6.000000e-01 reg 5.000000e-04 val accuracy: 0.552000
# nh 800 lr 6.000000e-01 reg 1.000000e-03 val accuracy: 0.571000
# nh 800 lr 6.000000e-01 reg 3.000000e-03 val accuracy: 0.546000
# nh 800 lr 7.000000e-01 reg 2.000000e-04 val accuracy: 0.543000
# nh 800 lr 7.000000e-01 reg 5.000000e-04 val accuracy: 0.541000
# nh 800 lr 7.000000e-01 reg 1.000000e-03 val accuracy: 0.523000
# nh 800 lr 7.000000e-01 reg 3.000000e-03 val accuracy: 0.563000
# nh 800 lr 8.000000e-01 reg 2.000000e-04 val accuracy: 0.527000
# nh 800 lr 8.000000e-01 reg 5.000000e-04 val accuracy: 0.550000
# nh 800 lr 8.000000e-01 reg 1.000000e-03 val accuracy: 0.526000
# nh 800 lr 8.000000e-01 reg 3.000000e-03 val accuracy: 0.544000
# nh 800 lr 9.000000e-01 reg 2.000000e-04 val accuracy: 0.540000
# nh 800 lr 9.000000e-01 reg 5.000000e-04 val accuracy: 0.515000
# nh 800 lr 9.000000e-01 reg 1.000000e-03 val accuracy: 0.528000
# nh 800 lr 9.000000e-01 reg 3.000000e-03 val accuracy: 0.507000
# nh 800 lr 1.000000e+00 reg 2.000000e-04 val accuracy: 0.550000
# nh 800 lr 1.000000e+00 reg 5.000000e-04 val accuracy: 0.551000
# nh 800 lr 1.000000e+00 reg 1.000000e-03 val accuracy: 0.541000
# nh 800 lr 1.000000e+00 reg 3.000000e-03 val accuracy: 0.540000
# best validation accuracy achieved during cross-validation: 0.575000
# hyperparameters (hidden_size, learning_rate, reg) are (800, 0.5, 0.0002)

# %%
# Visualize the cross-validation results
import math

x_scatter = [math.log10(x[1]) for x in results]
y_scatter = [math.log10(x[2]) for x in results]

# plot validation accuracy
marker_size = 100
colors = [results[x] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.556

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8

# First provide images that our system gets RIGHT
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test == cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# Then provide images that our system gets WRONG
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
